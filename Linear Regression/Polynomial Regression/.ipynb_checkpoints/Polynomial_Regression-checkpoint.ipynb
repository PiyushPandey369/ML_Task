# %% [markdown]
# ## Implementation of Polynomial Regression

# %% [markdown]
# #### Importing Essential Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %% [markdown]
# #### Creating Feature and Dependent Variable using random()

# %%
X = 6 * np.random.rand(200, 1) - 3
y = 0.8 * X**2 + 0.9 * X + 2 + np.random.randn(200, 1)
# y = 0.8x^2 + 0.9x + 2

# %%
plt.plot(X,y,'b.')
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# #### First training data with Linear Regression model and Comparing r2_score

# %%
model_lin = LinearRegression()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
model_lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lin = model_lin.predict(X_test)

# %%
r2_score(y_test,y_pred_lin)
# Out:
# 0.29812056056860636

# %%
model_lin.coef_
# Out:
# array([[1.15198479]])

# %%
model_lin.intercept_
# Out:
# array([4.5650275])

# %%
Y_plot = model_lin.coef_*X_train+model_lin.intercept_

# %% [markdown]
# #### Plotting best fit line to the datapoints

# %%
plt.plot(X_train,Y_plot,color='r')
plt.plot(X, y, "b.")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### Applying Polynomial Function

# %% [markdown]
# #### Transforming the data

# %%
poly = PolynomialFeatures(degree=2,include_bias=True)
X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.fit_transform(X_test)

# %%
print(X_train[0])
print(X_train_trans[0])
# Out:
# [0.81088144]
# [1.         0.81088144 0.65752872]

# %%
model_poly = LinearRegression()

# %%
model_poly.fit(X_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred_poly = model_poly.predict(X_test_trans)

# %%
r2_score(y_test,y_pred_poly)
# Out:
# 0.8975081822500419

# %%
model_poly.coef_.shape
# Out:
# (1, 3)

# %%
coeff = model_poly.coef_
coeff = coeff.ravel()

# %%
model_poly.intercept_
# Out:
# array([1.85974682])

# %%
X_new=np.linspace(-3, 3, 200).reshape(200, 1)
X_new_poly = poly.transform(X_new)
y_new = model_poly.predict(X_new_poly)

# %% [markdown]
# #### Plotting datapoints with the best fit curve

# %%
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions")
plt.plot(X_train, y_train, "b.",label='Training points')
plt.plot(X_test, y_test, "g.",label='Testing points')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# #### Conclusion:
# ```Model``` | ```r2_score```
#
# ``` LinearRegression ``` | ```0.170```
#
# ``` PolynomialRegression (degree=2)``` | ```0.83```

# %% [markdown]
# #### Code from scratch

# %%
# a = X^-1 * B

# %%
X = np.array([1,2,3,4])
y = np.array([1,4,9,15])

# %%
class My_PolynomialRegression:
    def __init__(self,degree=2):
        self.X_X = np.zeros((degree+1,degree+1))
        self.B= np.zeros((degree+1,1))
        self.a = None
    def fit (self,X_train,y_train,degree=2):
        for i in range(degree+1):
            for j in range(degree+1):
                self.X_X[i, j] = np.sum(X_train**(i+j))
        self.X_X[0,0] = len(X)
        for i in range(degree+1):
            self.B = np.sum((X_train**i)*y_train)
        self.a = (np.linalg.inv(self.X_X) @ self.B).ravel()
        return self.a
    def predict_poly(self,X_test):
        y_pred = np.zeros_like(self.X_X, dtype=float)
        for i in range(len(a)):
            y_pred += self.a[i] * X_test**i
        return y_pred

# %%
my_poly = My_PolynomialRegression()
my_poly.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 my_poly = My_PolynomialRegression()
# ----> 2 my_poly.fit(X,y)
#
# Cell In[49], line 13, in My_PolynomialRegression.fit(self, X_train, y_train, degree)
#      11 for i in range(degree+1):
#      12     self.B = np.sum((X_train**i)*y_train)
# ---> 13 self.a = (np.linalg.inv(self.X_X) @ B).ravel()
#      14 return self.a
#
# NameError: name 'B' is not defined

# %%
y_predicted_values = predict_poly(X)

# %%
plt.plot(X,y,"b.")
plt.plot(X,y_predicted_values,color="r")
plt.show()
